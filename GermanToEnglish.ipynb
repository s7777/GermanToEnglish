# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'deu.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-german.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-german.pkl
# [go] => [geh]
# [hi] => [hallo]
# [hi] => [gru gott]
# [run] => [lauf]
# [run] => [lauf]
# [wow] => [potzdonner]
# [wow] => [donnerwetter]
# [fire] => [feuer]
# [help] => [hilfe]
# [help] => [zu hulf]
# [stop] => [stopp]
# [wait] => [warte]
# [wait] => [warte]
# [begin] => [fang an]
# [go on] => [mach weiter]
# [hello] => [hallo]
# [hurry] => [beeil dich]
# [hurry] => [schnell]
# [i hid] => [ich versteckte mich]
# [i hid] => [ich habe mich versteckt]
# [i ran] => [ich rannte]
# [i see] => [ich verstehe]
# [i see] => [aha]
# [i try] => [ich probiere es]
# [i won] => [ich hab gewonnen]
# [i won] => [ich habe gewonnen]
# [relax] => [entspann dich]
# [shoot] => [feuer]
# [shoot] => [schie]
# [smile] => [lacheln]
# [ask me] => [frag mich]
# [ask me] => [fragt mich]
# [ask me] => [fragen sie mich]
# [attack] => [angriff]
# [attack] => [attacke]
# [cheers] => [zum wohl]
# [eat it] => [iss es]
# [eat up] => [iss auf]
# [eat up] => [iss auf]
# [freeze] => [keine bewegung]
# [freeze] => [stehenbleiben]
# [go now] => [geh jetzt]
# [got it] => [verstanden]
# [got it] => [aha]
# [got it] => [ich habs]
# [got it] => [kapiert]
# [got it] => [verstanden]
# [got it] => [einverstanden]
# [he ran] => [er rannte]
# [he ran] => [er lief]
# [hop in] => [mach mit]
# [hop in] => [spring rein]
# [hug me] => [druck mich]
# [hug me] => [nimm mich in den arm]
# [hug me] => [umarme mich]
# [i care] => [mir ist es wichtig]
# [i fell] => [ich fiel]
# [i fell] => [ich fiel hin]
# [i fell] => [ich sturzte]
# [i fell] => [ich bin hingefallen]
# [i fell] => [ich bin gesturzt]
# [i fled] => [ich fluchtete]
# [i fled] => [ich bin gefluchtet]
# [i know] => [ich wei]
# [i lied] => [ich habe gelogen]
# [i lost] => [ich habe verloren]
# [i paid] => [ich habe bezahlt]
# [i paid] => [ich zahlte]
# [i sang] => [ich sang]
# [i spit] => [ich spuckte]
# [i spit] => [ich habe gespuckt]
# [i swim] => [ich schwimme]
# [i wept] => [ich weinte]
# [i wept] => [ich habe geweint]
# [im] => [ich bin jahre alt]
# [im] => [ich bin]
# [im ok] => [mir gehts gut]
# [im ok] => [es geht mir gut]
# [im up] => [ich bin wach]
# [im up] => [ich bin auf]
# [no way] => [unmoglich]
# [no way] => [das kommt nicht in frage]
# [no way] => [das gibts doch nicht]
# [no way] => [ausgeschlossen]
# [no way] => [in keinster weise]
# [really] => [wirklich]
# [really] => [echt]
# [really] => [im ernst]
# [thanks] => [danke]
# [try it] => [versuchs]
# [we try] => [wir versuchen es]
# [we won] => [wir haben gewonnen]
# [why me] => [warum ich]
# [ask tom] => [frag tom]
# [ask tom] => [fragen sie tom]
# [ask tom] => [fragt tom]
# [awesome] => [fantastisch]
# [be cool] => [entspann dich]
# [be fair] => [sei nicht ungerecht]
# [be fair] => [sei fair]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-german.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-german-both.pkl')
save_clean_data(train, 'english-german-train.pkl')
save_clean_data(test, 'english-german-test.pkl')
# Out:
# Saved: english-german-both.pkl
# Saved: english-german-train.pkl
# Saved: english-german-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('German Vocabulary Size: %d' % ger_vocab_size)
print('German Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2241
# English Max Length: 5
# German Vocabulary Size: 3572
# German Max Length: 9
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 9, 256)            914432
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 5, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 2241)           575937
# =================================================================
# Total params: 2,540,993
# Trainable params: 2,540,993
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 33s - loss: 4.1421 - val_loss: 3.3258
#
# Epoch 00001: val_loss improved from inf to 3.32577, saving model to model.h5
# Epoch 2/100
# 141/141 - 27s - loss: 3.2219 - val_loss: 3.1191
#
# Epoch 00002: val_loss improved from 3.32577 to 3.11911, saving model to model.h5
# Epoch 3/100
# 141/141 - 27s - loss: 3.0812 - val_loss: 3.0013
#
# Epoch 00003: val_loss improved from 3.11911 to 3.00134, saving model to model.h5
# Epoch 4/100
# 141/141 - 27s - loss: 2.9505 - val_loss: 2.8370
#
# Epoch 00004: val_loss improved from 3.00134 to 2.83701, saving model to model.h5
# Epoch 5/100
# 141/141 - 27s - loss: 2.7853 - val_loss: 2.6930
#
# Epoch 00005: val_loss improved from 2.83701 to 2.69302, saving model to model.h5
# Epoch 6/100
# 141/141 - 27s - loss: 2.6482 - val_loss: 2.5592
#
# Epoch 00006: val_loss improved from 2.69302 to 2.55918, saving model to model.h5
# Epoch 7/100
# 141/141 - 27s - loss: 2.5099 - val_loss: 2.4193
#
# Epoch 00007: val_loss improved from 2.55918 to 2.41932, saving model to model.h5
# Epoch 8/100
# 141/141 - 27s - loss: 2.3676 - val_loss: 2.2758
#
# Epoch 00008: val_loss improved from 2.41932 to 2.27578, saving model to model.h5
# Epoch 9/100
# 141/141 - 27s - loss: 2.2200 - val_loss: 2.1425
#
# Epoch 00009: val_loss improved from 2.27578 to 2.14251, saving model to model.h5
# Epoch 10/100
# 141/141 - 27s - loss: 2.0780 - val_loss: 2.0012
#
# Epoch 00010: val_loss improved from 2.14251 to 2.00122, saving model to model.h5
# Epoch 11/100
# 141/141 - 27s - loss: 1.9444 - val_loss: 1.8828
#
# Epoch 00011: val_loss improved from 2.00122 to 1.88276, saving model to model.h5
# Epoch 12/100
# 141/141 - 27s - loss: 1.8170 - val_loss: 1.7639
#
# Epoch 00012: val_loss improved from 1.88276 to 1.76386, saving model to model.h5
# Epoch 13/100
# 141/141 - 27s - loss: 1.7006 - val_loss: 1.6481
#
# Epoch 00013: val_loss improved from 1.76386 to 1.64805, saving model to model.h5
# Epoch 14/100
# 141/141 - 27s - loss: 1.5926 - val_loss: 1.5617
#
# Epoch 00014: val_loss improved from 1.64805 to 1.56166, saving model to model.h5
# Epoch 15/100
# 141/141 - 27s - loss: 1.4877 - val_loss: 1.4651
#
# Epoch 00015: val_loss improved from 1.56166 to 1.46515, saving model to model.h5
# Epoch 16/100
# 141/141 - 28s - loss: 1.3886 - val_loss: 1.3632
#
# Epoch 00016: val_loss improved from 1.46515 to 1.36317, saving model to model.h5
# Epoch 17/100
# 141/141 - 28s - loss: 1.2943 - val_loss: 1.3059
#
# Epoch 00017: val_loss improved from 1.36317 to 1.30591, saving model to model.h5
# Epoch 18/100
# 141/141 - 29s - loss: 1.2045 - val_loss: 1.1994
#
# Epoch 00018: val_loss improved from 1.30591 to 1.19937, saving model to model.h5
# Epoch 19/100
# 141/141 - 28s - loss: 1.1120 - val_loss: 1.1187
#
# Epoch 00019: val_loss improved from 1.19937 to 1.11873, saving model to model.h5
# Epoch 20/100
# 141/141 - 28s - loss: 1.0295 - val_loss: 1.0475
#
# Epoch 00020: val_loss improved from 1.11873 to 1.04749, saving model to model.h5
# Epoch 21/100
# 141/141 - 29s - loss: 0.9515 - val_loss: 0.9756
#
# Epoch 00021: val_loss improved from 1.04749 to 0.97565, saving model to model.h5
# Epoch 22/100
# 141/141 - 28s - loss: 0.8759 - val_loss: 0.9099
#
# Epoch 00022: val_loss improved from 0.97565 to 0.90989, saving model to model.h5
# Epoch 23/100
# 141/141 - 28s - loss: 0.8046 - val_loss: 0.8492
#
# Epoch 00023: val_loss improved from 0.90989 to 0.84922, saving model to model.h5
# Epoch 24/100
# 141/141 - 27s - loss: 0.7374 - val_loss: 0.7809
#
# Epoch 00024: val_loss improved from 0.84922 to 0.78090, saving model to model.h5
# Epoch 25/100
# 141/141 - 27s - loss: 0.6761 - val_loss: 0.7433
#
# Epoch 00025: val_loss improved from 0.78090 to 0.74328, saving model to model.h5
# Epoch 26/100
# 141/141 - 27s - loss: 0.6191 - val_loss: 0.6916
#
# Epoch 00026: val_loss improved from 0.74328 to 0.69155, saving model to model.h5
# Epoch 27/100
# 141/141 - 28s - loss: 0.5685 - val_loss: 0.6496
#
# Epoch 00027: val_loss improved from 0.69155 to 0.64957, saving model to model.h5
# Epoch 28/100
# 141/141 - 28s - loss: 0.5163 - val_loss: 0.6007
#
# Epoch 00028: val_loss improved from 0.64957 to 0.60072, saving model to model.h5
# Epoch 29/100
# 141/141 - 28s - loss: 0.4705 - val_loss: 0.5676
#
# Epoch 00029: val_loss improved from 0.60072 to 0.56759, saving model to model.h5
# Epoch 30/100
# 141/141 - 27s - loss: 0.4310 - val_loss: 0.5355
#
# Epoch 00030: val_loss improved from 0.56759 to 0.53554, saving model to model.h5
# Epoch 31/100
# 141/141 - 28s - loss: 0.3960 - val_loss: 0.5050
#
# Epoch 00031: val_loss improved from 0.53554 to 0.50501, saving model to model.h5
# Epoch 32/100
# 141/141 - 28s - loss: 0.3605 - val_loss: 0.4828
#
# Epoch 00032: val_loss improved from 0.50501 to 0.48278, saving model to model.h5
# Epoch 33/100
# 141/141 - 27s - loss: 0.3340 - val_loss: 0.4604
#
# Epoch 00033: val_loss improved from 0.48278 to 0.46039, saving model to model.h5
# Epoch 34/100
# 141/141 - 27s - loss: 0.3074 - val_loss: 0.4380
#
# Epoch 00034: val_loss improved from 0.46039 to 0.43804, saving model to model.h5
# Epoch 35/100
# 141/141 - 27s - loss: 0.2812 - val_loss: 0.4227
#
# Epoch 00035: val_loss improved from 0.43804 to 0.42271, saving model to model.h5
# Epoch 36/100
# 141/141 - 28s - loss: 0.2615 - val_loss: 0.4045
#
# Epoch 00036: val_loss improved from 0.42271 to 0.40452, saving model to model.h5
# Epoch 37/100
# 141/141 - 28s - loss: 0.2405 - val_loss: 0.3935
#
# Epoch 00037: val_loss improved from 0.40452 to 0.39351, saving model to model.h5
# Epoch 38/100
# 141/141 - 27s - loss: 0.2271 - val_loss: 0.3844
#
# Epoch 00038: val_loss improved from 0.39351 to 0.38442, saving model to model.h5
# Epoch 39/100
# 141/141 - 27s - loss: 0.2128 - val_loss: 0.3706
#
# Epoch 00039: val_loss improved from 0.38442 to 0.37057, saving model to model.h5
# Epoch 40/100
# 141/141 - 28s - loss: 0.1986 - val_loss: 0.3572
#
# Epoch 00040: val_loss improved from 0.37057 to 0.35719, saving model to model.h5
# Epoch 41/100
# 141/141 - 27s - loss: 0.1858 - val_loss: 0.3558
#
# Epoch 00041: val_loss improved from 0.35719 to 0.35575, saving model to model.h5
# Epoch 42/100
# 141/141 - 27s - loss: 0.1762 - val_loss: 0.3460
#
# Epoch 00042: val_loss improved from 0.35575 to 0.34599, saving model to model.h5
# Epoch 43/100
# 141/141 - 27s - loss: 0.1673 - val_loss: 0.3426
#
# Epoch 00043: val_loss improved from 0.34599 to 0.34264, saving model to model.h5
# Epoch 44/100
# 141/141 - 27s - loss: 0.1583 - val_loss: 0.3388
#
# Epoch 00044: val_loss improved from 0.34264 to 0.33883, saving model to model.h5
# Epoch 45/100
# 141/141 - 27s - loss: 0.1516 - val_loss: 0.3284
#
# Epoch 00045: val_loss improved from 0.33883 to 0.32836, saving model to model.h5
# Epoch 46/100
# 141/141 - 27s - loss: 0.1454 - val_loss: 0.3252
#
# Epoch 00046: val_loss improved from 0.32836 to 0.32518, saving model to model.h5
# Epoch 47/100
# 141/141 - 27s - loss: 0.1397 - val_loss: 0.3224
#
# Epoch 00047: val_loss improved from 0.32518 to 0.32237, saving model to model.h5
# Epoch 48/100
# 141/141 - 27s - loss: 0.1340 - val_loss: 0.3191
#
# Epoch 00048: val_loss improved from 0.32237 to 0.31910, saving model to model.h5
# Epoch 49/100
# 141/141 - 27s - loss: 0.1290 - val_loss: 0.3142
#
# Epoch 00049: val_loss improved from 0.31910 to 0.31416, saving model to model.h5
# Epoch 50/100
# 141/141 - 26s - loss: 0.1252 - val_loss: 0.3113
#
# Epoch 00050: val_loss improved from 0.31416 to 0.31133, saving model to model.h5
# Epoch 51/100
# 141/141 - 27s - loss: 0.1209 - val_loss: 0.3125
#
# Epoch 00051: val_loss did not improve from 0.31133
# Epoch 52/100
# 141/141 - 26s - loss: 0.1185 - val_loss: 0.3076
#
# Epoch 00052: val_loss improved from 0.31133 to 0.30763, saving model to model.h5
# Epoch 53/100
# 141/141 - 26s - loss: 0.1163 - val_loss: 0.3078
#
# Epoch 00053: val_loss did not improve from 0.30763
# Epoch 54/100
# 141/141 - 26s - loss: 0.1119 - val_loss: 0.3053
#
# Epoch 00054: val_loss improved from 0.30763 to 0.30530, saving model to model.h5
# Epoch 55/100
# 141/141 - 26s - loss: 0.1102 - val_loss: 0.3051
#
# Epoch 00055: val_loss improved from 0.30530 to 0.30510, saving model to model.h5
# Epoch 56/100
# 141/141 - 27s - loss: 0.1094 - val_loss: 0.3034
#
# Epoch 00056: val_loss improved from 0.30510 to 0.30343, saving model to model.h5
# Epoch 57/100
# 141/141 - 26s - loss: 0.1076 - val_loss: 0.3057
#
# Epoch 00057: val_loss did not improve from 0.30343
# Epoch 58/100
# 141/141 - 26s - loss: 0.1075 - val_loss: 0.3049
#
# Epoch 00058: val_loss did not improve from 0.30343
# Epoch 59/100
# 141/141 - 26s - loss: 0.1043 - val_loss: 0.3055
#
# Epoch 00059: val_loss did not improve from 0.30343
# Epoch 60/100
# 141/141 - 27s - loss: 0.1039 - val_loss: 0.3020
#
# Epoch 00060: val_loss improved from 0.30343 to 0.30199, saving model to model.h5
# Epoch 61/100
# 141/141 - 26s - loss: 0.1012 - val_loss: 0.3031
#
# Epoch 00061: val_loss did not improve from 0.30199
# Epoch 62/100
# 141/141 - 26s - loss: 0.0993 - val_loss: 0.2997
#
# Epoch 00062: val_loss improved from 0.30199 to 0.29966, saving model to model.h5
# Epoch 63/100
# 141/141 - 26s - loss: 0.0977 - val_loss: 0.2997
#
# Epoch 00063: val_loss did not improve from 0.29966
# Epoch 64/100
# 141/141 - 26s - loss: 0.0948 - val_loss: 0.2992
#
# Epoch 00064: val_loss improved from 0.29966 to 0.29920, saving model to model.h5
# Epoch 65/100
# 141/141 - 26s - loss: 0.0947 - val_loss: 0.3009
#
# Epoch 00065: val_loss did not improve from 0.29920
# Epoch 66/100
# 141/141 - 26s - loss: 0.0942 - val_loss: 0.3063
#
# Epoch 00066: val_loss did not improve from 0.29920
# Epoch 67/100
# 141/141 - 26s - loss: 0.0938 - val_loss: 0.2999
#
# Epoch 00067: val_loss did not improve from 0.29920
# Epoch 68/100
# 141/141 - 26s - loss: 0.0922 - val_loss: 0.3004
#
# Epoch 00068: val_loss did not improve from 0.29920
# Epoch 69/100
# 141/141 - 26s - loss: 0.0929 - val_loss: 0.2994
#
# Epoch 00069: val_loss did not improve from 0.29920
# Epoch 70/100
# 141/141 - 26s - loss: 0.0914 - val_loss: 0.3000
#
# Epoch 00070: val_loss did not improve from 0.29920
# Epoch 71/100
# 141/141 - 26s - loss: 0.0910 - val_loss: 0.2975
#
# Epoch 00071: val_loss improved from 0.29920 to 0.29753, saving model to model.h5
# Epoch 72/100
# 141/141 - 26s - loss: 0.0906 - val_loss: 0.3011
#
# Epoch 00072: val_loss did not improve from 0.29753
# Epoch 73/100
# 141/141 - 26s - loss: 0.0913 - val_loss: 0.3022
#
# Epoch 00073: val_loss did not improve from 0.29753
# Epoch 74/100
# 141/141 - 26s - loss: 0.0898 - val_loss: 0.3001
#
# Epoch 00074: val_loss did not improve from 0.29753
# Epoch 75/100
# 141/141 - 26s - loss: 0.0882 - val_loss: 0.2968
#
# Epoch 00075: val_loss improved from 0.29753 to 0.29685, saving model to model.h5
# Epoch 76/100
# 141/141 - 26s - loss: 0.0881 - val_loss: 0.3002
#
# Epoch 00076: val_loss did not improve from 0.29685
# Epoch 77/100
# 141/141 - 26s - loss: 0.0864 - val_loss: 0.2996
#
# Epoch 00077: val_loss did not improve from 0.29685
# Epoch 78/100
# 141/141 - 26s - loss: 0.0864 - val_loss: 0.3008
#
# Epoch 00078: val_loss did not improve from 0.29685
# Epoch 79/100
# 141/141 - 26s - loss: 0.0856 - val_loss: 0.3007
#
# Epoch 00079: val_loss did not improve from 0.29685
# Epoch 80/100
# 141/141 - 26s - loss: 0.0837 - val_loss: 0.3009
#
# Epoch 00080: val_loss did not improve from 0.29685
# Epoch 81/100
# 141/141 - 26s - loss: 0.0844 - val_loss: 0.2988
#
# Epoch 00081: val_loss did not improve from 0.29685
# Epoch 82/100
# 141/141 - 26s - loss: 0.0845 - val_loss: 0.3030
#
# Epoch 00082: val_loss did not improve from 0.29685
# Epoch 83/100
# 141/141 - 27s - loss: 0.0839 - val_loss: 0.3008
#
# Epoch 00083: val_loss did not improve from 0.29685
# Epoch 84/100
# 141/141 - 27s - loss: 0.0829 - val_loss: 0.3018
#
# Epoch 00084: val_loss did not improve from 0.29685
# Epoch 85/100
# 141/141 - 26s - loss: 0.0833 - val_loss: 0.2994
#
# Epoch 00085: val_loss did not improve from 0.29685
# Epoch 86/100
# 141/141 - 26s - loss: 0.0827 - val_loss: 0.3025
#
# Epoch 00086: val_loss did not improve from 0.29685
# Epoch 87/100
# 141/141 - 26s - loss: 0.0822 - val_loss: 0.3059
#
# Epoch 00087: val_loss did not improve from 0.29685
# Epoch 88/100
# 141/141 - 26s - loss: 0.0827 - val_loss: 0.3035
#
# Epoch 00088: val_loss did not improve from 0.29685
# Epoch 89/100
# 141/141 - 26s - loss: 0.0823 - val_loss: 0.3025
#
# Epoch 00089: val_loss did not improve from 0.29685
# Epoch 90/100
# 141/141 - 26s - loss: 0.0833 - val_loss: 0.3026
#
# Epoch 00090: val_loss did not improve from 0.29685
# Epoch 91/100
# 141/141 - 26s - loss: 0.0832 - val_loss: 0.3029
#
# Epoch 00091: val_loss did not improve from 0.29685
# Epoch 92/100
# 141/141 - 26s - loss: 0.0843 - val_loss: 0.3069
#
# Epoch 00092: val_loss did not improve from 0.29685
# Epoch 93/100
# 141/141 - 26s - loss: 0.0844 - val_loss: 0.3118
#
# Epoch 00093: val_loss did not improve from 0.29685
# Epoch 94/100
# 141/141 - 26s - loss: 0.0857 - val_loss: 0.3067
#
# Epoch 00094: val_loss did not improve from 0.29685
# Epoch 95/100
# 141/141 - 26s - loss: 0.0835 - val_loss: 0.3036
#
# Epoch 00095: val_loss did not improve from 0.29685
# Epoch 96/100
# 141/141 - 26s - loss: 0.0810 - val_loss: 0.3045
#
# Epoch 00096: val_loss did not improve from 0.29685
# Epoch 97/100
# 141/141 - 26s - loss: 0.0803 - val_loss: 0.3031
#
# Epoch 00097: val_loss did not improve from 0.29685
# Epoch 98/100
# 141/141 - 26s - loss: 0.0788 - val_loss: 0.3043
#
# Epoch 00098: val_loss did not improve from 0.29685
# Epoch 99/100
# 141/141 - 27s - loss: 0.0780 - val_loss: 0.3032
#
# Epoch 00099: val_loss did not improve from 0.29685
# Epoch 100/100
# 141/141 - 26s - loss: 0.0788 - val_loss: 0.3044
#
# Epoch 00100: val_loss did not improve from 0.29685

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,train = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[rot steht ihnen], target=[red suits you], predicted=[red suits you]
# src=[schicken sie es mir], target=[send it to me], predicted=[send it to me]
# src=[das war tom], target=[that was tom], predicted=[that was tom]
# src=[wie tief ist das], target=[how deep is it], predicted=[how deep is it]
# src=[das ist eine puppe], target=[thats a doll], predicted=[thats a doll]
# src=[meine lungen schmerzten], target=[my lungs hurt], predicted=[my lungs hurt]
# src=[ich fuhle mit dir mit], target=[i sympathize], predicted=[i sympathize]
# src=[dies ist mein hund], target=[this is my dog], predicted=[this is my dog]
# src=[bildet zwei reihen], target=[form two lines], predicted=[form two lines]
# src=[schreibt mir], target=[write me], predicted=[write me]
# BLEU-1: 0.947716
# BLEU-2: 0.930372
# BLEU-3: 0.846458
# BLEU-4: 0.516752
# test
# src=[du bist gro], target=[youre big], predicted=[you are big]
# src=[tom fahrt auto], target=[tom drives], predicted=[tom drives driving]
# src=[ich habe tom getroffen], target=[i met tom], predicted=[i met tom]
# src=[hilf mir mal], target=[give me a hand], predicted=[give me a hand]
# src=[ich kam mir wie ein blodmann vor], target=[i felt dumb], predicted=[i felt dumb]
# src=[bringen sie es mir], target=[bring it to me], predicted=[bring it to me]
# src=[tom ist gerade gegangen], target=[tom just left], predicted=[tom just left]
# src=[das habe ich geschrieben], target=[i wrote that], predicted=[i wrote that]
# src=[sie arbeiten tuchtig], target=[they work hard], predicted=[they work hard]
# src=[ich war besturzt], target=[i was upset], predicted=[i was upset]
# BLEU-1: 0.909170
# BLEU-2: 0.881683
# BLEU-3: 0.798403
# BLEU-4: 0.478521

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[rot steht ihnen], target=[red suits you], predicted=[red suits you]
# src=[schicken sie es mir], target=[send it to me], predicted=[send it to me]
# src=[das war tom], target=[that was tom], predicted=[that was tom]
# src=[wie tief ist das], target=[how deep is it], predicted=[how deep is it]
# src=[das ist eine puppe], target=[thats a doll], predicted=[thats a doll]
# src=[meine lungen schmerzten], target=[my lungs hurt], predicted=[my lungs hurt]
# src=[ich fuhle mit dir mit], target=[i sympathize], predicted=[i sympathize]
# src=[dies ist mein hund], target=[this is my dog], predicted=[this is my dog]
# src=[bildet zwei reihen], target=[form two lines], predicted=[form two lines]
# src=[schreibt mir], target=[write me], predicted=[write me]
# BLEU-1: 0.947716
# BLEU-2: 0.930372
# BLEU-3: 0.846458
# BLEU-4: 0.516752
# test
# src=[du bist gro], target=[youre big], predicted=[you are big]
# src=[tom fahrt auto], target=[tom drives], predicted=[tom drives driving]
# src=[ich habe tom getroffen], target=[i met tom], predicted=[i met tom]
# src=[hilf mir mal], target=[give me a hand], predicted=[give me a hand]
# src=[ich kam mir wie ein blodmann vor], target=[i felt dumb], predicted=[i felt dumb]
# src=[bringen sie es mir], target=[bring it to me], predicted=[bring it to me]
# src=[tom ist gerade gegangen], target=[tom just left], predicted=[tom just left]
# src=[das habe ich geschrieben], target=[i wrote that], predicted=[i wrote that]
# src=[sie arbeiten tuchtig], target=[they work hard], predicted=[they work hard]
# src=[ich war besturzt], target=[i was upset], predicted=[i was upset]
# BLEU-1: 0.909170
# BLEU-2: 0.881683
# BLEU-3: 0.798403
# BLEU-4: 0.478521
